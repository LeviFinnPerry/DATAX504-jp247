# %% [markdown]
# # Assignment 2 — Keras MNIST Classifier
#
# **DATAX504** · Due end of Week 4
#
# ## Tasks
# 1. Dense classifier on MNIST — test accuracy **without** dropout
# 2. Same architecture **with** dropout — compare train vs val curves
# 3. Confusion matrix → worst confused digit pair
# 4. Explain why `sparse_categorical_crossentropy` is appropriate
#
# ## Moodle fields
# `a2_repo`, `a2_test_acc`, `a2_test_acc_do`, `a2_worst_pair`, `a2_crossentropy`

# %% [markdown]
# ## AI disclosure
#
# Fill in before submission (see Assignment 1 template).

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import keras
from keras import layers

# %% [markdown]
# ## 1. Load MNIST

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

x_train_flat = x_train.reshape(-1, 28 * 28)
x_test_flat = x_test.reshape(-1, 28 * 28)

num_classes = 10
print(x_train_flat.shape, y_train.shape)
# Out:
# (60000, 784) (60000,)

# %% [markdown]
# ## 2. Validation split

# %%
val_samples = 10000
x_val = x_train_flat[:val_samples]
y_val = y_train[:val_samples]
x_train_flat = x_train_flat[val_samples:]
y_train = y_train[val_samples:]

print("Train:", x_train_flat.shape[0], "Val:", x_val.shape[0], "Test:", x_test_flat.shape[0])
# Out:
# Train: 50000 Val: 10000 Test: 10000

# %% [markdown]
# ## 3. Model builder
#
# TODO: adjust hidden units if needed. Keep architecture comparable between runs.

# %%
def build_model(use_dropout=False, dropout_rate=0.3):
    model = keras.Sequential([
        layers.Input(shape=(784,)),
        layers.Dense(512, activation="relu"),
        layers.Dense(256, activation="relu"),
    ])
    if use_dropout:
        model.add(layers.Dropout(dropout_rate))
    model.add(layers.Dense(num_classes, activation="softmax"))
    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

# %% [markdown]
# ## 4. Train baseline (no dropout)

# %%
EPOCHS = 20
BATCH_SIZE = 128

model_baseline = build_model(use_dropout=False)
history_baseline = model_baseline.fit(
    x_train_flat, y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(x_val, y_val),
    verbose=1,
)

test_loss, test_acc = model_baseline.evaluate(x_test_flat, y_test, verbose=0)
print(f"Baseline test accuracy (Moodle a2_test_acc): {test_acc:.4f}")
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9281 - loss: 0.2498 - val_accuracy: 0.9660 - val_loss: 0.1191
# Epoch 2/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9721 - loss: 0.0901 - val_accuracy: 0.9711 - val_loss: 0.0948
# Epoch 3/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9826 - loss: 0.0551 - val_accuracy: 0.9721 - val_loss: 0.0929
# Epoch 4/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9878 - loss: 0.0383 - val_accuracy: 0.9748 - val_loss: 0.0812
# Epoch 5/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9907 - loss: 0.0280 - val_accuracy: 0.9769 - val_loss: 0.0770
# Epoch 6/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9928 - loss: 0.0215 - val_accuracy: 0.9743 - val_loss: 0.0882
# Epoch 7/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9940 - loss: 0.0181 - val_accuracy: 0.9774 - val_loss: 0.0920
# Epoch 8/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9946 - loss: 0.0168 - val_accuracy: 0.9777 - val_loss: 0.0921
# Epoch 9/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9954 - loss: 0.0146 - val_accuracy: 0.9789 - val_loss: 0.0831
# Epoch 10/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9970 - loss: 0.0095 - val_accuracy: 0.9745 - val_loss: 0.1115
# Epoch 11/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9953 - loss: 0.0160 - val_accuracy: 0.9756 - val_loss: 0.0956
# Epoch 12/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9963 - loss: 0.0119 - val_accuracy: 0.9776 - val_loss: 0.1013
# Epoch 13/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9954 - loss: 0.0120 - val_accuracy: 0.9805 - val_loss: 0.0802
# Epoch 14/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9977 - loss: 0.0077 - val_accuracy: 0.9802 - val_loss: 0.0923
# Epoch 15/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9979 - loss: 0.0067 - val_accuracy: 0.9809 - val_loss: 0.0945
# Epoch 16/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9969 - loss: 0.0095 - val_accuracy: 0.9767 - val_loss: 0.1093
# Epoch 17/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9973 - loss: 0.0080 - val_accuracy: 0.9786 - val_loss: 0.1058
# Epoch 18/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9969 - loss: 0.0083 - val_accuracy: 0.9784 - val_loss: 0.1146
# Epoch 19/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9969 - loss: 0.0091 - val_accuracy: 0.9806 - val_loss: 0.0920
# Epoch 20/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9983 - loss: 0.0050 - val_accuracy: 0.9819 - val_loss: 0.0970
# Baseline test accuracy (Moodle a2_test_acc): 0.9811

# %% [markdown]
# ## 5. Train with dropout

# %%
model_dropout = build_model(use_dropout=True, dropout_rate=0.3)
history_dropout = model_dropout.fit(
    x_train_flat, y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(x_val, y_val),
    verbose=1,
)

_, test_acc_do = model_dropout.evaluate(x_test_flat, y_test, verbose=0)
print(f"Dropout test accuracy (Moodle a2_test_acc_do): {test_acc_do:.4f}")
# Out:
# Epoch 1/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9179 - loss: 0.2753 - val_accuracy: 0.9645 - val_loss: 0.1201
# Epoch 2/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9686 - loss: 0.1060 - val_accuracy: 0.9728 - val_loss: 0.0887
# Epoch 3/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9787 - loss: 0.0694 - val_accuracy: 0.9756 - val_loss: 0.0778
# Epoch 4/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9849 - loss: 0.0475 - val_accuracy: 0.9758 - val_loss: 0.0787
# Epoch 5/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9872 - loss: 0.0385 - val_accuracy: 0.9793 - val_loss: 0.0735
# Epoch 6/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9907 - loss: 0.0279 - val_accuracy: 0.9787 - val_loss: 0.0722
# Epoch 7/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9923 - loss: 0.0228 - val_accuracy: 0.9797 - val_loss: 0.0744
# Epoch 8/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9938 - loss: 0.0191 - val_accuracy: 0.9762 - val_loss: 0.0909
# Epoch 9/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9942 - loss: 0.0171 - val_accuracy: 0.9787 - val_loss: 0.0829
# Epoch 10/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9949 - loss: 0.0151 - val_accuracy: 0.9831 - val_loss: 0.0702
# Epoch 11/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9952 - loss: 0.0139 - val_accuracy: 0.9796 - val_loss: 0.0922
# Epoch 12/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9957 - loss: 0.0131 - val_accuracy: 0.9814 - val_loss: 0.0797
# Epoch 13/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9965 - loss: 0.0100 - val_accuracy: 0.9812 - val_loss: 0.0900
# Epoch 14/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9963 - loss: 0.0113 - val_accuracy: 0.9782 - val_loss: 0.0926
# Epoch 15/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9965 - loss: 0.0114 - val_accuracy: 0.9776 - val_loss: 0.1132
# Epoch 16/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9962 - loss: 0.0114 - val_accuracy: 0.9805 - val_loss: 0.0903
# Epoch 17/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9969 - loss: 0.0095 - val_accuracy: 0.9808 - val_loss: 0.0989
# Epoch 18/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9977 - loss: 0.0069 - val_accuracy: 0.9795 - val_loss: 0.1087
# Epoch 19/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9972 - loss: 0.0086 - val_accuracy: 0.9798 - val_loss: 0.1033
# Epoch 20/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9962 - loss: 0.0117 - val_accuracy: 0.9818 - val_loss: 0.1011
# Dropout test accuracy (Moodle a2_test_acc_do): 0.9816

# %% [markdown]
# ## 6. Compare learning curves

# %%
def plot_histories(histories, labels, metric="loss"):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    for hist, label in zip(histories, labels):
        axes[0].plot(hist.history[metric], label=f"{label} train")
        axes[0].plot(hist.history[f"val_{metric}"], linestyle="--", label=f"{label} val")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel(metric)
    axes[0].legend()
    axes[0].set_title(f"Training vs validation {metric}")
    axes[0].grid(True, alpha=0.3)
    # accuracy panel
    for hist, label in zip(histories, labels):
        axes[1].plot(hist.history["accuracy"], label=f"{label} train")
        axes[1].plot(hist.history["val_accuracy"], linestyle="--", label=f"{label} val")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("accuracy")
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

plot_histories([history_baseline, history_dropout], ["baseline", "dropout"])

# %% [markdown]
# ## 7. Confusion matrix

# %%
y_pred = np.argmax(model_dropout.predict(x_test_flat, verbose=0), axis=1)
cm = confusion_matrix(y_test, y_pred)

fig, ax = plt.subplots(figsize=(8, 7))
im = ax.imshow(cm, cmap="Blues")
plt.colorbar(im)
ax.set_xlabel("Predicted")
ax.set_ylabel("True")
ax.set_title("MNIST confusion matrix (dropout model)")
plt.show()

# TODO: find off-diagonal maximum → worst pair for Moodle a2_worst_pair
cm_off = cm.copy()
np.fill_diagonal(cm_off, 0)
true_i, pred_j = np.unravel_index(np.argmax(cm_off), cm_off.shape)
print(f"Worst confused pair (Moodle a2_worst_pair): {true_i}-{pred_j} ({cm_off[true_i, pred_j]} errors)")
# Out:
# Worst confused pair (Moodle a2_worst_pair): 4-9 (13 errors)

# %% [markdown]
# ## 8. Why sparse categorical crossentropy? (Moodle `a2_crossentropy`)
#
# Write up to 150 words explaining:
# - What integer labels look like vs one-hot
# - What the loss computes
# - Why this pairs with a softmax output

# %% [markdown]
# *Your answer here.*
